# %%
#4258 only has jet variability
source='NGC4258'
faclow=0.702
faclow=(2+faclow)/(2-faclow)

valchosen=6.9
valchosenerr=1.1
print(f'{source}: direct')
print(f'{valchosen} ± {valchosenerr}\n' )

valdust=0.8
valdusterr=0.3
print( f'{source}: dust')
print(f'{valdust} ± {valdusterr}\n' )

print(faclow)
valjet=0.14
valjeterr=0.02
valjetvarup=valjet*faclow-valjet
valjetvarlow=valjet-valjet/faclow
print(f'{source}: jet')
print(f'{valjet} $^{{+{valjetvarup:.1f}}}_{{-{valjetvarlow:.1f}}}$ ± {valjeterr}\n' )

# %%
#no available variability for NGC 1194

# %%
#3079 only has jet variability
#no submill
source='NGC3079'

valchosen=35.5 
valchosenerr=2.3
valchosenvarup=valchosen*faclow-valchosen
valchosenvarlow=valchosen-valchosen/faclow
print(f'{source}: direct')
print(f'{valchosen} ± {valchosenerr}\n' )

faclow=1.334
faclow=(2+faclow)/(2-faclow)
print(faclow)
valjet=0.487
valjeterr=0.04
valjetvarup=valjet*faclow-valjet
valjetvarlow=valjet-valjet/faclow
print(f'{source}: jet')
print(f'{valjet} $^{{+{valjetvarup:.1f}}}_{{-{valjetvarlow:.1f}}}$ ± {valjeterr}\n' )

# %%
#4945 only has mm-sub-mm variability
#no jet variability
source='NGC4945'
fachigh=0.335

valchosen=15.8
valchosenerr=0.3

valdust=0.704
valdusterr=0.041

fac=(2+fachigh)/(2-fachigh)
print(fac)

valchosenvarup=valchosen*fac-valchosen
valchosenvarlow=valchosen-valchosen/fac
print(f'{source}: direct')
print(f'{valchosen} $^{{+{valchosenvarup:.1f}}}_{{-{valchosenvarlow:.1f}}}$ ± {valchosenerr}\n' )

print( f'{source}: dust')
print(f'{valdust} ± {valdusterr}\n' )

# %%
#circinus only has mm-sub-mm variability
#no jet variability

source='Circinus'
fachigh=0.157

valchosen=14.27
valchosenerr=0.02

valdust=6.99e-04
valdusterr=3.1e-05


fac=(2+fachigh)/(2-fachigh)
print(fac)

valchosenvarup=valchosen*fac-valchosen
valchosenvarlow=valchosen-valchosen/fac
print(f'{source}: direct')
print(f'{valchosen} $^{{+{valchosenvarup:.1f}}}_{{-{valchosenvarlow:.1f}}}$ ± {valchosenerr}\n' )

print( f'{source}: dust')
print(f'{valdust} ± {valdusterr}\n' )

valjet=6.7
valjeterr=0.67

print(f'{source}: jet')
print(f'{faclow:.1f}')
print(f'{valjet} ± {valjeterr}\n' )

# %%
#ngc1068 only has mm-sub-mm as well as jet variability
#weighted variability conducted
source='NGC 1068'
faclow=0.602
fachigh=0.232

valchosen=6.74
valchosenerr=0.04

#valdust=0.00475
#valdusterr=0.00021
valdust=12.20
SNR=28.699
valdusterr=12.20/28.699


tot=valchosen+valdust

subdust=(valchosen)/(tot)*(faclow)+(valdust)/(tot)*(fachigh)
fac=(2+subdust)/(2-subdust)
print(fac)

valchosenvarup=valchosen*fac-valchosen
valchosenvarlow=valchosen-valchosen/fac
print(f'{source}: direct')
print(f'{valchosen} $^{{+{valchosenvarup:.1f}}}_{{-{valchosenvarlow:.1f}}}$ ± {valchosenerr}\n' )


print( f'{source}: dust')
print(f'{valdust} ± {valdusterr}\n' )


faclow=0.568
valjet=0.11307
valjeterr=0.00003
faclow=(2+faclow)/(2-faclow)
print(faclow)
valjetvarup=valjet*faclow-valjet
valjetvarlow=valjet-valjet/faclow
print(f'{source}: jet')
print(f'{valjet} $^{{+{valjetvarup:.1f}}}_{{-{valjetvarlow:.2f}}}$ ± {valjeterr}\n' )
